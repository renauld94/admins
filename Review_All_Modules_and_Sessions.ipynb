# %% [markdown]
# # J&J Python Academy: Review All Modules, Sessions, and Visuals
#
# This notebook provides a comprehensive review of all course modules and sessions, demonstrates how to load and display sample notebooks as slides, generates visual summaries, and integrates with external model APIs (Ollama, OpenWebUI) for advanced analysis.

# %% [markdown]
# ## 1. Import Required Libraries
#
# Import libraries for notebook handling, visualization, and API integration.

# %%
# Import Required Libraries
import os
import nbformat
from nbconvert import SlidesExporter
import matplotlib.pyplot as plt
import requests
from IPython.display import display, Markdown, HTML

# %% [markdown]
# ## 2. List and Load Sample Notebooks
#
# Scan a directory for available sample notebooks and load their metadata for review.

# %%
# List and load sample notebooks from a directory
notebook_dir = './'
sample_notebooks = [f for f in os.listdir(notebook_dir) if f.endswith('.ipynb') and f != os.path.basename(__file__)]
print('Sample Notebooks Found:')
for nb in sample_notebooks:
    print('-', nb)
# Load metadata for the first notebook as an example
if sample_notebooks:
    with open(os.path.join(notebook_dir, sample_notebooks[0]), 'r') as f:
        nb_data = nbformat.read(f, as_version=4)
    print('Title:', nb_data['cells'][0]['source'][:80])

# %% [markdown]
# ## 3. Display Notebooks as Slides
#
# Convert selected notebooks to slides using nbconvert and display them within the notebook.

# %%
# Convert a notebook to slides and display HTML (for the first sample notebook)
if sample_notebooks:
    exporter = SlidesExporter()
    slides_html, _ = exporter.from_filename(os.path.join(notebook_dir, sample_notebooks[0]))
    display(HTML(slides_html))

# %% [markdown]
# ## 4. Generate Visual Summaries of Notebooks
#
# Extract key information from notebooks and generate visual summaries using matplotlib or other visualization libraries.

# %%
# Visualize the number of code vs markdown cells in the first sample notebook
if sample_notebooks:
    code_count = sum(1 for cell in nb_data['cells'] if cell['cell_type'] == 'code')
    md_count = sum(1 for cell in nb_data['cells'] if cell['cell_type'] == 'markdown')
    plt.bar(['Code', 'Markdown'], [code_count, md_count], color=['#1976d2', '#d51920'])
    plt.title('Cell Type Distribution in Sample Notebook')
    plt.ylabel('Count')
    plt.show()

# %% [markdown]
# ## 5. Review All Modules and Sessions
#
# Programmatically list all modules and sessions, summarizing their content and structure.

# %%
# List all modules and sessions from the course content file
import json
with open('python_academy_course_contents.json', 'r') as f:
    course_data = json.load(f)
for module in course_data:
    print(f"Module: {module['name']}")
    if 'modules' in module and module['modules']:
        for session in module['modules']:
            print(f"  - Session: {session['name']}")
    else:
        print("  (No sessions listed)")

# %% [markdown]
# ## 6. Integrate with External Model APIs
#
# Demonstrate how to connect to external model APIs (Ollama, OpenWebUI) for enhanced analysis or summarization.

# %%
# Example: Call Ollama or OpenWebUI API for summarization (replace URL and payload as needed)
ollama_url = 'https://ollama.simondatalab.de/api/generate'
openwebui_url = 'https://openwebui.simondatalab.de/api/generate'

payload = {
    'model': 'llama2',
    'prompt': 'Summarize the structure of the J&J Python Academy course.'
}

try:
    response = requests.post(ollama_url, json=payload, timeout=10)
    if response.ok:
        print('Ollama summary:', response.json().get('summary', response.text))
    else:
        print('Ollama API error:', response.status_code)
except Exception as e:
    print('Ollama API call failed:', e)

# Repeat for OpenWebUI if desired

# %% [markdown]
# # JNJ Python Academy — LMS Transformation Plan
#
# This section tracks the course polish, LTI 1.3 integration with Databricks, and BigBlueButton rollout for Course ID 2 on moodle.simondatalab.de.
#
# - Course: JNJ-Python-Academy (Clinical Programming & SDTM Data Engineering)
# - Moodle Course URL: https://moodle.simondatalab.de/course/view.php?id=2
# - Databricks Workspace: https://dbc-b975c647-8055.cloud.databricks.com
# - BigBlueButton: integrated via Moodle activity
#
# Objectives:
# - Visually stunning course interface (banner, section cards, activity polish, progress)
# - LTI 1.3 links to Databricks per module with grade passback
# - Scheduled BBB sessions with calendar + recordings

# %% [markdown]
# ## Visual Enhancements — Course ID 2
#
# - Header banner: gradient with clinical blues and subtle purple accent
# - Section cards: shadow, rounded radius, hover lift
# - Activities: compact, clear titles, subtle hover background
# - Progress bars: thicker, rounded, primary brand color
# - Mobile-responsive paddings and grid
#
# Status: Deployed via `learning-platform/moodle-simondatalab.css` and verified via curl.

# %% [markdown]
# ## LTI 1.3 — Databricks Integration Plan
#
# Tool (Databricks)
# - Issuer (iss): https://dbc-b975c647-8055.cloud.databricks.com
# - Platform: Moodle (LTI 1.3 consumer)
# - Auth: OAuth 2.0 (OIDC), JWKs, RS256
#
# Implementation steps
# 1. Create OAuth app / LTI registration in Databricks; obtain auth, token, jwks, and launch endpoints.
# 2. In Moodle (Site admin → Plugins → External tool → Manage tools): Add tool using openid-configuration URL.
# 3. Enable LTI Advantage: Deep Linking + Names & Roles + Assignment & Grade Services.
# 4. Create course activities (External tool) per module folder path; enable grading where applicable.
# 5. Test launch flows; verify id_token claims and roles; adjust role mappings.
# 6. Implement grade passback for assignments using AGS endpoints.
#
# Security
# - Enforce RS256 signature verification and nonce checks.
# - Restrict to course context and enrolled roles only.

# %% [markdown]
# ## BigBlueButton Rollout — Sessions & Settings
#
# Server & plugin
# - BigBlueButton server connected to Moodle (or hosted service)
# - Moodle BBB activity enabled
#
# Settings defaults
# - Recording: ON, auto-publish to course page
# - Max participants: 50
# - Lock meeting after start (allow instructor override)
# - Captions: enable auto transcription
#
# Scheduling
# - Lectures: Mondays 10:00 UTC, Deep Dives Wednesdays 15:00 UTC
# - Labs: align with modules (e.g., Module 3 PySpark)
# - Office hours: daily 30m
# - Capstone reviews: Module 6
#
# Calendar & notifications
# - Sync to course calendar, email reminders (1w/1d/1h/15m)

# %%
# Tracking checklist for integration (toggle states as you progress)
checklist = {
    "visual_course_2": True,
    "lti_registration": False,
    "deep_links_created": False,
    "grade_passback_tested": False,
    "bbb_sessions_scheduled": False,
    "notifications_configured": False,
    "accessibility_audit": False,
}
checklist
