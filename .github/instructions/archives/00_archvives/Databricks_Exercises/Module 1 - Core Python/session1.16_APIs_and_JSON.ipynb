# %% [markdown]
# # Session 1.16: APIs and JSON
#
# ## **Common for Ingesting Data from APIs and Parsing Input Files**
#
# ### **Learning Objectives**
# By the end of this session, you will:
# - Understand how to interact with APIs in Python
# - Parse and process JSON data
# - Apply API and JSON skills to healthcare data ingestion
# - Prepare for PySpark's JSON and REST integrations
#
# ---
#
# ### **Relevance to PySpark**
# APIs and JSON are essential for ingesting external data and working with semi-structured sources in PySpark workflows.
#
# ---

# %% [markdown]
# ## 1. Accessing Healthcare Data via APIs

# %%
# Example: Fetching healthcare data from a public API
import requests
response = requests.get('https://api.publicapis.org/entries')
if response.status_code == 200:
    data = response.json()
    print('Number of APIs listed:', len(data['entries']))
else:
    print('Failed to fetch data')

# %% [markdown]
# ## 2. Parsing JSON Data

# %%
# Example: Parsing patient data from JSON
import json
patient_json = '{"id": "PT001", "name": "John Doe", "age": 45, "diagnosis": "Hypertension"}'
patient = json.loads(patient_json)
print('Patient name:', patient['name'])

# %% [markdown]
# ## 3. Practice Exercise
#
# Write code to fetch and parse JSON data for a list of healthcare providers from a sample API.

# %%
# Exercise: Fetch and parse healthcare provider data
# TODO: Use requests to get JSON data and parse provider names
# Your code here

# %% [markdown]
# ---
#
# ## Summary
#
# In this session, you learned:
# - ✅ How to access APIs in Python
# - ✅ How to parse and process JSON data
# - ✅ How to ingest healthcare data from external sources
# - ✅ Essential skills for PySpark's API and JSON integrations
#
# **End of Module 1 - Core Python**
