# %% [markdown]
# # Session 1.7: Dates and Times
#
# ## **Important for Timestamp Data Handling**
#
# ### **Learning Objectives**
# By the end of this session, you will:
# - Work with Python's datetime module
# - Parse, format, and manipulate dates and times
# - Apply date/time logic to healthcare scenarios
# - Prepare timestamp data for PySpark DataFrames
#
# ---
#
# ### **Relevance to PySpark**
# Handling dates and times is essential for timestamped healthcare data and PySpark time-based operations.
#
# ---

# %% [markdown]
# ## 1. Working with datetime Module

# %% [markdown]
# from datetime import datetime, timedelta
#
# # Current date and time
# now = datetime.now()
# print(f"Current date and time: {now}")
#
# # Formatting dates
# formatted = now.strftime('%Y-%m-%d %H:%M:%S')
# print(f"Formatted: {formatted}")
#
# # Parsing date strings
# date_str = '2025-07-25'
# parsed_date = datetime.strptime(date_str, '%Y-%m-%d')
# print(f"Parsed date: {parsed_date}")

# %% [markdown]
# ## 2. Date Arithmetic and Time Deltas

# %% [markdown]
# # Calculate time difference
# admission = datetime(2025, 7, 20, 14, 30)
# discharge = datetime(2025, 7, 25, 10, 0)
#
# length_of_stay = discharge - admission
# print(f"Length of stay: {length_of_stay.days} days, {length_of_stay.seconds//3600} hours")

# %% [markdown]
# ## 3. Working with Timestamps in Healthcare Data

# %% [markdown]
# # Example: Patient vital sign timestamps
# vital_signs = [
#     {'timestamp': '2025-07-20 14:30', 'bp': '140/90'},
#     {'timestamp': '2025-07-21 09:00', 'bp': '135/85'},
#     {'timestamp': '2025-07-22 16:15', 'bp': '130/80'}
# ]
#
# for vs in vital_signs:
#     ts = datetime.strptime(vs['timestamp'], '%Y-%m-%d %H:%M')
#     print(f"{ts}: BP {vs['bp']}")

# %% [markdown]
# ## 4. Practice Exercise
#
# Write code to calculate the average time between patient visits.

# %% [markdown]
# # Exercise: Average time between visits
# visit_dates = ['2025-07-20', '2025-07-22', '2025-07-25']
#
# # TODO: Calculate average days between visits
# # Your code here

# %% [markdown]
# ---
#
# ## Summary
#
# In this session, you learned:
# - ✅ How to work with Python's datetime module
# - ✅ How to parse, format, and manipulate dates and times
# - ✅ How to apply date/time logic to healthcare scenarios
# - ✅ Essential skills for timestamp data in PySpark
#
# **Next:** Session 1.8 - Regular Expressions
