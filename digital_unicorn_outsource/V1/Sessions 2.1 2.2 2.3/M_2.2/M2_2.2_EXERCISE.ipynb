# %% [markdown]
# # Session 2.2 #

# %% [markdown]
# ## Exercise A ##
# Example using an f-string.
#
# 📝 Task:
#
# * Create a variable PATIENT_NAME with the value `"Alice"`
# * Create a variable PATIENT_AGE with the value `30`
# * Print both values in one sentence: `Alice is 30 years old`
#
# ✅ Solution

# %%
PATIENT_NAME = "Alice"
PATIENT_AGE = 30

PATIENT_TEXT = f"{PATIENT_NAME} is {PATIENT_AGE} years old"
print(PATIENT_TEXT)
# Out:
# Alice is 30 years old

# %% [markdown]
# ## Exercise B ##
# Use the multiplication operator
#
# 📝 Task:
#
# A patient takes 2 mg of a drug 3 times a day for 5 days. Calculate the total dose.
#
# ✅ Solution

# %%
DOSE_PER_INTAKE = 2
TIMES_PER_DAY = 3
DAYS = 5

TOTAL_DOSE = DOSE_PER_INTAKE * TIME_PER_DAY * DAYS
print(TOTAL_DOSE)
# Out:
# 30

# %% [markdown]
# ## Exercise C ##
# Use of randint method
#
# 📝 Task:
#
# * You need to add import random at the top of your program lines.
# * call the randint method
# * like `NUMBER=random.randint(1,10)` will generate any number form 1 to 10
# * Print the random number: `print(number)`
#
# ✅ Solution

# %%
import random

NUMBER=random.randint(1,10)

print(NUMBER)
# Out:
# 9

# %% [markdown]
# ## Exercise D ##
# 📝 Task:
#
# Assign two variables the boolean values, _True_ and _False_ and print out the value of the intersection of the two variables using the keyword _and_
#
# ✅ Solution

# %%
POSITIVE = True
NEGATIVE = False
POS_NEG = POSITIVE and NEGATIVE
print(POS_NEG)
# Out:
# False

# %% [markdown]
# ## Exercise E ##
# 📝 Task:
#
# 1. Print out the result of whether:
#     - `POSITIVE = True` is equal to `NEGATIVE = False`
#     - `POSITIVE = True` is not equal to `NEGATIVE = False`
#
# ✅ Solution

# %%
print(POSITIVE == NEGATIVE)
print(POSITIVE != NEGATIVE)
# Out:
# False
# True

# %% [markdown]
# ## Exercise F ##
# 📝 Task:
#
# Use the function bool to calculate if the string literal `MILD` is a falsy or truthy value, i.e. _False_ or _True_
#
# ✅ Solution

# %%
bool("MILD")
# Out:
# {'type': 'mimeBundle', 'data': {'text/plain': 'True'}, 'executionCount': 16, 'arguments': {}, 'addedWidgets': {}, 'removedWidgets': [], 'datasetInfos': [], 'metadata': {'kernelSessionId': '0805107a-e4f92c18bad90cc88322f418'}}
